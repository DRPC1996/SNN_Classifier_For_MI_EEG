# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\USER\anaconda3\envs\classifier\lib\site-packages\IPython\core\magics\pylab.py:162: UserWarning: pylab import has clobbered these variables: ['step', 'psd', 'beta', 'cov', 'dtype']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

import snntorch as snn
from snntorch import spikeplot as splt
from snntorch import spikegen

import numpy as np

import scipy.io
import scipy.signal 

from matplotlib import mlab
import matplotlib.pyplot as plt

# %%
def psd(trials):
    
    ntrials = trials.shape[2]
    trials_PSD = np.zeros((nchannels, 101, ntrials))

    # Iterate over trials and channels
    for trial in range(ntrials):
        for ch in range(nchannels):
            # Calculate the PSD
            (PSD, freqs) = mlab.psd(trials[ch,:,trial], NFFT=int(nsamples), Fs=sample_rate)
            trials_PSD[ch, :, trial] = PSD.ravel()
                
    return trials_PSD, freqs


def plot_psd(trials_PSD, freqs, chan_ind, chan_lab=None, maxy=None):
    plt.figure(figsize=(12,5))
    
    nchans = len(chan_ind)
    
    # Maximum of 3 plots per row
    nrows = int(np.ceil(nchans / 3))
    ncols = min(3, nchans)
    
    # Enumerate over the channels
    for i,ch in enumerate(chan_ind):
        # Figure out which subplot to draw to
        plt.subplot(nrows,ncols,i+1)
    
        # Plot the PSD for each class
        for cl in trials.keys():
            plt.plot(freqs, np.mean(trials_PSD[cl][ch,:,:], axis=1), label=cl)
    
        # All plot decoration below...
        
        plt.xlim(1,30)
        
        if maxy != None:
            plt.ylim(0,maxy)
    
        plt.grid()
    
        plt.xlabel('Frequency (Hz)')
        
        if chan_lab == None:
            plt.title('Channel %d' % (ch+1))
        else:
            plt.title(chan_lab[i])

        plt.legend()
        
    plt.tight_layout()

def bandpass(trials, lo, hi, sample_rate):
 
    a, b = scipy.signal.iirfilter(6, [lo/(sample_rate/2.0), hi/(sample_rate/2.0)])

    ntrials = trials.shape[2]
    trials_filt = np.zeros((nchannels, nsamples, ntrials))
    for i in range(ntrials):
        trials_filt[:,:,i] = scipy.signal.filtfilt(a, b, trials[:,:,i], axis=1)
    
    return trials_filt

def logvar(trials):
    return np.var(trials, axis=1)

def plot_logvar(trials, trial_no = None):
    plt.figure(figsize=(12,5))

    print(trials[cl1].shape)
    
    x0 = np.arange(nchannels)
    x1 = np.arange(nchannels) + 0.4

    if trial_no == None:
        y0 = np.mean(trials[cl1], axis=1)
        y1 = np.mean(trials[cl2], axis=1)
    else:
        y0 = trials[cl1][:,trial_no]
        y1 = trials[cl2][:,trial_no]

    plt.bar(x0, y0, width=0.5, color='b')
    plt.bar(x1, y1, width=0.4, color='r')

    plt.xlim(-0.5, nchannels+0.5)

    plt.gca().yaxis.grid(True)
    plt.title('log-var of each channel/component')
    plt.xlabel('channels/components')
    plt.ylabel('log-var')
    plt.legend(cl_lab)

from numpy import linalg

def cov(trials):
    ntrials = trials.shape[2]
    covs = [ trials[:,:,i].dot(trials[:,:,i].T) / nsamples for i in range(ntrials) ]
    return np.mean(covs, axis=0)

def whitening(sigma):
    U, l, _ = linalg.svd(sigma)
    return U.dot( np.diag(l ** -0.5) )

def csp(trials_r, trials_f):
    cov_r = cov(trials_r)
    cov_f = cov(trials_f)
    P = whitening(cov_r + cov_f)
    B, _, _ = linalg.svd( P.T.dot(cov_f).dot(P) )
    W = P.dot(B)
    return W

def apply_mix(W, trials):
    ntrials = trials.shape[2]
    trials_csp = np.zeros((nchannels, nsamples, ntrials))
    for i in range(ntrials):
        trials_csp[:,:,i] = W.T.dot(trials[:,:,i])
    return trials_csp

import torch
import snntorch.spikeplot as splt
from snntorch import spikegen

def spike_latency(trials, trial_n, cls, num_steps):
    input_data = trials[cl1] if cls == 1 else trials[cl2]
    
    tensor = torch.tensor(input_data[:,trial_n])
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    tensor = tensor.to(device)
    
    spike_data = spikegen.latency(tensor, num_steps=num_steps, threshold=(np.mean(input_data[:,trial_n])+1)*1/2, bypass=True)

    return spike_data

def spike_rate(trials, trial_n, cls, num_steps):
    input_data = trials[cl1] if cls == 1 else trials[cl2]
    
    tensor = torch.tensor(input_data[:,trial_n])
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    tensor = tensor.to(device)
    
    spike_data = spikegen.rate(tensor, num_steps=num_steps)

    return spike_data

def plot_raster(spike_data):
    
    fig = plt.figure(facecolor="w", figsize=(10, 5))
    ax = fig.add_subplot(111)
    
    spike_data_sample = spike_data
    splt.raster(spike_data_sample, ax, s=1.5, c="black")
    plt.ylim(0, 60)
    
    plt.title("Input Layer")
    plt.xlabel("Time step")
    plt.ylabel("Neuron Number")
    plt.show()

def plot_snn_spikes(spk_in, spk1_rec, spk2_rec, num_steps, title):
  # Generate Plots
  fig, ax = plt.subplots(3, figsize=(8,7), sharex=True, 
                        gridspec_kw = {'height_ratios': [1, 1, 0.4]})

  # Plot input spikes
  splt.raster(spk_in[:,0], ax[0], s=0.1, c="black")
  ax[0].set_ylabel("Input Spikes")
  ax[0].set_title(title)

  # Plot hidden layer spikes
  splt.raster(spk1_rec.reshape(num_steps, -1), ax[1], s = 0.1, c="black")
  ax[1].set_ylabel("Hidden Layer")

  # Plot output spikes
  splt.raster(spk2_rec.reshape(num_steps, -1), ax[2], c="black", marker="|")
  ax[2].set_ylabel("Output Spikes")
  ax[2].set_ylim([0, 10])

  plt.show()

def plot_snn_spikes(spk_in, spk1_rec, spk2_rec, num_steps, title):
  # Generate Plots
  fig, ax = plt.subplots(3, figsize=(8,7), sharex=True, 
                        gridspec_kw = {'height_ratios': [1, 1, 0.4]})

  # Plot input spikes
  splt.raster(spk_in[:,0], ax[0], s=0.1, c="black")
  ax[0].set_ylabel("Input Spikes")
  ax[0].set_title(title)

  # Plot hidden layer spikes
  splt.raster(spk1_rec.reshape(num_steps, -1), ax[1], s = 0.1, c="black")
  ax[1].set_ylabel("Hidden Layer")

  # Plot output spikes
  splt.raster(spk2_rec.reshape(num_steps, -1), ax[2], c="black", marker="|")
  ax[2].set_ylabel("Output Spikes")
  ax[2].set_yticks([0, 1], ['left', 'right'])
  ax[2].set_ylim([-0.5, 1.5])


  plt.show()

def plot_snn_spikes_modified(spk_in, spk1_rec, spk2_rec, num_steps, title):
  # Generate Plots
  fig, ax = plt.subplots(3, figsize=(8,7), sharex=False, 
                        gridspec_kw = {'height_ratios': [1, 1, 0.4]})

  # Plot input spikes

  neuron_numbers = list(range(59))
  currents = spk_in.tolist()  # Currents fed to each neuron
    
  # Create bar chart
  ax[0].bar(neuron_numbers, currents, color='skyblue')
  ax[0].set_ylabel("Input Currents")
  ax[0].set_title(title)

  # Plot hidden layer spikes
  splt.raster(spk1_rec.reshape(num_steps, -1), ax[1], s = 0.1, c="black")
  ax[1].set_ylabel("Hidden Layer")

  # Plot output spikes
  splt.raster(spk2_rec.reshape(num_steps, -1), ax[2], c="black", marker="|")
  ax[2].set_ylabel("Output Spikes")
  ax[2].set_yticks([0, 1], ['left', 'right'])
  ax[2].set_ylim([-0.5, 1.5])


  plt.show()

# %%
m = scipy.io.loadmat('BCICIV_1_mat\BCICIV_calib_ds1d.mat', struct_as_record=True)

sample_rate = m['nfo']['fs'][0][0][0][0]
EEG = m['cnt'].T
nchannels, nsamples = EEG.shape

channel_names = [s[0] for s in m['nfo']['clab'][0][0][0]]
event_onsets = m['mrk'][0][0][0]
event_codes = m['mrk'][0][0][1]
labels = np.zeros((1, nsamples), int)
labels[0, event_onsets] = event_codes

cl_lab = [s[0] for s in m['nfo']['classes'][0][0][0]]
cl1 = cl_lab[0]
cl2 = cl_lab[1]
nclasses = len(cl_lab)
nevents = len(event_onsets)

# %%
trials = {}

win = np.arange(int(0.5*sample_rate), int(2.5*sample_rate))

nsamples = len(win)

for cl, code in zip(cl_lab, np.unique(event_codes)):
    
    cl_onsets = event_onsets[event_codes == code]

    trials[cl] = np.zeros((nchannels, nsamples, len(cl_onsets)))
    
    for i, onset in enumerate(cl_onsets):
        trials[cl][:,:,i] = EEG[:, win+onset]

# %%
trials_filt = {cl1: bandpass(trials[cl1], 2, 30, sample_rate),
               cl2: bandpass(trials[cl2], 2, 30, sample_rate)}

# %%
W = csp(trials_filt[cl1], trials_filt[cl2])
trials_csp = {cl1: apply_mix(W, trials_filt[cl1]),
              cl2: apply_mix(W, trials_filt[cl2])}

# %%
trials_logvar = {cl1: logvar(trials_csp[cl1]),
                 cl2: logvar(trials_csp[cl2])}

# %%
normalized_within_trial = {cl1: ((trials_logvar[cl1]-np.min(trials_logvar[cl1],axis=0))/(np.max(trials_logvar[cl1],axis=0)-np.min(trials_logvar[cl1],axis=0))),
                 cl2: ((trials_logvar[cl2]-np.min(trials_logvar[cl2],axis=0))/(np.max(trials_logvar[cl2],axis=0)-np.min(trials_logvar[cl2],axis=0)))}

# %%
max_value = np.max(trials_logvar[cl1]) or np.max(trials_logvar[cl2])
min_value = np.min(trials_logvar[cl1]) or np.min(trials_logvar[cl2])


normalized_trials_logvar = {cl1: ((trials_logvar[cl1]-min_value)/(max_value-min_value)),
                 cl2: ((trials_logvar[cl2]-min_value)/(max_value-min_value))}

# %%
dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader

class CustomDataset(Dataset):
    def __init__(self, data):
        self.data = data

    def __len__(self):
        if len(self.data.shape) > 1:
            return self.data.shape[1]
        else:
            return 1

    def __getitem__(self, idx):
        sample = self.data[1:,idx]
        label = self.data[0,idx]
        return torch.tensor(sample, dtype=torch.float32), torch.tensor(label, dtype=torch.long)

# %%
data = normalized_within_trial

# Additional column for class identifiers
class_column_left = np.zeros((1, 100))  # Assuming all instances belong to class 0
class_column_right = np.ones((1, 100))  # Assuming all instances belong to class 0

# Concatenate class column along with left and right arrays
left_with_class = np.concatenate([class_column_left, data['left']], axis=0)
right_with_class = np.concatenate([class_column_right, data['right']], axis=0)

# Concatenate left and right arrays along axis 1
result = np.concatenate([left_with_class, right_with_class], axis=1)

cl1_split_idx = int(result.shape[1]*0.5*0.8)
cl2_split_idx = int(result.shape[1]*0.5*1.8)

train_data = np.concatenate([result[:, :cl1_split_idx],result[:, 100:cl2_split_idx]], axis=1)
test_data = np.concatenate([result[:, cl1_split_idx:100],result[:, cl2_split_idx:]], axis=1)

# Create CustomDataset instance
train_dataset = CustomDataset(train_data)
test_dataset = CustomDataset(test_data)

# Create DataLoader
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

for samples, labels in train_loader:
    # Your training code here
    print(samples.shape, labels.shape)
# Out:
# torch.Size([32, 59]) torch.Size([32])
# torch.Size([32, 59]) torch.Size([32])
# torch.Size([32, 59]) torch.Size([32])
# torch.Size([32, 59]) torch.Size([32])
# torch.Size([32, 59]) torch.Size([32])
# C:\Users\USER\AppData\Local\Temp\ipykernel_7188\1880285545.py:18: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   return torch.tensor(sample, dtype=torch.float32), torch.tensor(label, dtype=torch.long)

# %%
test_data.shape
# Out:
# (60, 40)

# %%
num_inputs = 59
num_hidden = 1000
num_outputs = 2
beta = 0.99

# %%
# Define Network
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        # Initialize layers
        self.fc1 = nn.Linear(num_inputs, num_hidden)
        self.lif1 = snn.Leaky(beta=beta)
        self.fc2 = nn.Linear(num_hidden, num_outputs)
        self.lif2 = snn.Leaky(beta=beta)

        self.spkIn = []
        self.spk1 = []
        self.spk2 = []

    def forward(self, x):

        # Initialize hidden states at t=0
        mem1 = self.lif1.init_leaky()
        mem2 = self.lif2.init_leaky()

        self.spkIn = []
        self.spk1 = []
        self.spk2 = []
        
        # Record the final layer
        spk2_rec = []
        mem2_rec = []

        for step in range(num_steps):
            cur1 = self.fc1(x)
            spk1, mem1 = self.lif1(cur1, mem1)
            cur2 = self.fc2(spk1)
            spk2, mem2 = self.lif2(cur2, mem2)

            self.spkIn.append(x)
            self.spk1.append(spk1)
            self.spk2.append(spk2)
            
            spk2_rec.append(spk2)
            mem2_rec.append(mem2)

        return torch.stack(spk2_rec, dim=0), torch.stack(mem2_rec, dim=0)
        
# Load the network onto CUDA if available
net = Net().to(device)

# %%
def print_batch_accuracy(data, targets, train=False):
    output, _ = net(data.view(batch_size, -1))
    _, idx = output.sum(dim=0).max(1)
    acc = np.mean((targets == idx).detach().cpu().numpy())

    if train:
        print(f"Train set accuracy for a single minibatch: {acc*100:.2f}%")
    else:
        print(f"Test set accuracy for a single minibatch: {acc*100:.2f}%")

def train_printer(
    data, targets, epoch,
    counter, iter_counter,
        loss_hist, test_loss_hist, test_data, test_targets):
    print(f"Epoch {epoch}, Iteration {iter_counter}")
    print(f"Train Set Loss: {loss_hist[counter]:.2f}")
    print(f"Test Set Loss: {test_loss_hist[counter]:.2f}")
    print_batch_accuracy(data, targets, train=True)
    print_batch_accuracy(test_data, test_targets, train=False)
    print("\n")

# %%
loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=5e-4, betas=(0.9, 0.999))

# %%
num_epochs = 20
loss_hist = []
test_loss_hist = []
counter = 0
i=0
num_steps = 25

# Outer training loop
for epoch in range(num_epochs):
    iter_counter = 0
    train_batch = iter(train_loader)

    # Minibatch training loop
    for data, targets in train_batch:
        data = data.to(device)
        targets = targets.to(device)
        i=i+1
        print(i)

        # forward pass
        net.train()
        spk_rec, mem_rec = net(data.view(batch_size, -1))

        # initialize the loss & sum over time
        loss_val = torch.zeros((1), dtype=dtype, device=device)
        for step in range(num_steps):
            loss_val += loss(mem_rec[step], targets)

        # Gradient calculation + weight update
        optimizer.zero_grad()
        loss_val.backward()
        optimizer.step()

        # Store loss history for future plotting
        loss_hist.append(loss_val.item())

        # Test set
        with torch.no_grad():
            net.eval()
            test_data, test_targets = next(iter(test_loader))
            test_data = test_data.to(device)
            test_targets = test_targets.to(device)

            # Test set forward pass
            test_spk, test_mem = net(test_data.view(batch_size, -1))

            # Test set loss
            test_loss = torch.zeros((1), dtype=dtype, device=device)
            for step in range(num_steps):
                test_loss += loss(test_mem[step], test_targets)
            test_loss_hist.append(test_loss.item())

            # Print train/test loss/accuracy
            if counter % 1 == 0:
                train_printer(
                    data, targets, epoch,
                    counter, iter_counter,
                    loss_hist, test_loss_hist,
                    test_data, test_targets)
            counter += 1
            iter_counter +=1
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7188\1880285545.py:18: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   return torch.tensor(sample, dtype=torch.float32), torch.tensor(label, dtype=torch.long)
# 1
# Epoch 0, Iteration 0
# Train Set Loss: 19.79
# Test Set Loss: 22.96
# Train set accuracy for a single minibatch: 46.88%
# Test set accuracy for a single minibatch: 62.50%
#
#
# 2
# Epoch 0, Iteration 1
# Train Set Loss: 15.89
# Test Set Loss: 19.81
# Train set accuracy for a single minibatch: 37.50%
# Test set accuracy for a single minibatch: 62.50%
#
#
# 3
# Epoch 0, Iteration 2
# Train Set Loss: 19.33
# Test Set Loss: 12.39
# Train set accuracy for a single minibatch: 43.75%
# Test set accuracy for a single minibatch: 62.50%
#
#
# 4
# Epoch 0, Iteration 3
# Train Set Loss: 12.74
# Test Set Loss: 10.62
# Train set accuracy for a single minibatch: 56.25%
# Test set accuracy for a single minibatch: 62.50%
#
#
# 5
# Epoch 0, Iteration 4
# Train Set Loss: 10.83
# Test Set Loss: 12.33
# Train set accuracy for a single minibatch: 65.62%
# Test set accuracy for a single minibatch: 62.50%
#
#
# 6
# Epoch 1, Iteration 0
# Train Set Loss: 14.09
# Test Set Loss: 11.67
# Train set accuracy for a single minibatch: 56.25%
# Test set accuracy for a single minibatch: 62.50%
#
#
# 7
# Epoch 1, Iteration 1
# Train Set Loss: 15.45
# Test Set Loss: 8.98
# Train set accuracy for a single minibatch: 37.50%
# Test set accuracy for a single minibatch: 62.50%
#
#
# 8
# Epoch 1, Iteration 2
# Train Set Loss: 9.22
# Test Set Loss: 7.18
# Train set accuracy for a single minibatch: 53.12%
# Test set accuracy for a single minibatch: 62.50%
#
#
# 9
# Epoch 1, Iteration 3
# Train Set Loss: 8.90
# Test Set Loss: 6.61
# Train set accuracy for a single minibatch: 56.25%
# Test set accuracy for a single minibatch: 62.50%
#
#
# 10
# Epoch 1, Iteration 4
# Train Set Loss: 7.97
# Test Set Loss: 6.72
# Train set accuracy for a single minibatch: 65.62%
# Test set accuracy for a single minibatch: 71.88%
#
#
# 11
# Epoch 2, Iteration 0
# Train Set Loss: 7.04
# Test Set Loss: 6.72
# Train set accuracy for a single minibatch: 65.62%
# Test set accuracy for a single minibatch: 78.12%
#
#
# 12
# Epoch 2, Iteration 1
# Train Set Loss: 7.23
# Test Set Loss: 6.40
# Train set accuracy for a single minibatch: 68.75%
# Test set accuracy for a single minibatch: 81.25%
#
#
# 13
# Epoch 2, Iteration 2
# Train Set Loss: 8.59
# Test Set Loss: 5.79
# Train set accuracy for a single minibatch: 59.38%
# Test set accuracy for a single minibatch: 81.25%
#
#
# 14
# Epoch 2, Iteration 3
# Train Set Loss: 6.75
# Test Set Loss: 5.19
# Train set accuracy for a single minibatch: 71.88%
# Test set accuracy for a single minibatch: 78.12%
#
#
# 15
# Epoch 2, Iteration 4
# Train Set Loss: 6.15
# Test Set Loss: 4.77
# Train set accuracy for a single minibatch: 65.62%
# Test set accuracy for a single minibatch: 75.00%
#
#
# 16
# Epoch 3, Iteration 0
# Train Set Loss: 5.31
# Test Set Loss: 4.57
# Train set accuracy for a single minibatch: 62.50%
# Test set accuracy for a single minibatch: 68.75%
#
#
# 17
# Epoch 3, Iteration 1
# Train Set Loss: 4.81
# Test Set Loss: 4.53
# Train set accuracy for a single minibatch: 56.25%
# Test set accuracy for a single minibatch: 68.75%
#
#
# 18
# Epoch 3, Iteration 2
# Train Set Loss: 5.68
# Test Set Loss: 4.54
# Train set accuracy for a single minibatch: 46.88%
# Test set accuracy for a single minibatch: 68.75%
#
#
# 19
# Epoch 3, Iteration 3
# Train Set Loss: 3.97
# Test Set Loss: 4.63
# Train set accuracy for a single minibatch: 75.00%
# Test set accuracy for a single minibatch: 68.75%
#
#
# 20
# Epoch 3, Iteration 4
# Train Set Loss: 5.72
# Test Set Loss: 4.60
# Train set accuracy for a single minibatch: 46.88%
# Test set accuracy for a single minibatch: 68.75%
#
#
# 21
# Epoch 4, Iteration 0
# Train Set Loss: 5.46
# Test Set Loss: 4.46
# Train set accuracy for a single minibatch: 46.88%
# Test set accuracy for a single minibatch: 68.75%
#
#
# 22
# Epoch 4, Iteration 1
# Train Set Loss: 4.63
# Test Set Loss: 4.29
# Train set accuracy for a single minibatch: 62.50%
# Test set accuracy for a single minibatch: 71.88%
#
#
# 23
# Epoch 4, Iteration 2
# Train Set Loss: 4.42
# Test Set Loss: 4.09
# Train set accuracy for a single minibatch: 68.75%
# Test set accuracy for a single minibatch: 71.88%
#
#
# 24
# Epoch 4, Iteration 3
# Train Set Loss: 4.18
# Test Set Loss: 3.90
# Train set accuracy for a single minibatch: 75.00%
# Test set accuracy for a single minibatch: 75.00%
#
#
# 25
# Epoch 4, Iteration 4
# Train Set Loss: 4.54
# Test Set Loss: 3.76
# Train set accuracy for a single minibatch: 71.88%
# Test set accuracy for a single minibatch: 81.25%
#
#
# 26
# Epoch 5, Iteration 0
# Train Set Loss: 3.90
# Test Set Loss: 3.62
# Train set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 81.25%
#
#
# 27
# Epoch 5, Iteration 1
# Train Set Loss: 3.75
# Test Set Loss: 3.53
# Train set accuracy for a single minibatch: 84.38%
# Test set accuracy for a single minibatch: 87.50%
#
#
# 28
# Epoch 5, Iteration 2
# Train Set Loss: 4.32
# Test Set Loss: 3.47
# Train set accuracy for a single minibatch: 65.62%
# Test set accuracy for a single minibatch: 87.50%
#
#
# 29
# Epoch 5, Iteration 3
# Train Set Loss: 3.96
# Test Set Loss: 3.40
# Train set accuracy for a single minibatch: 78.12%
# Test set accuracy for a single minibatch: 87.50%
#
#
# 30
# Epoch 5, Iteration 4
# Train Set Loss: 3.30
# Test Set Loss: 3.35
# Train set accuracy for a single minibatch: 81.25%
# Test set accuracy for a single minibatch: 90.62%
#
#
# 31
# Epoch 6, Iteration 0
# Train Set Loss: 4.07
# Test Set Loss: 3.31
# Train set accuracy for a single minibatch: 75.00%
# Test set accuracy for a single minibatch: 93.75%
#
#
# 32
# Epoch 6, Iteration 1
# Train Set Loss: 3.37
# Test Set Loss: 3.27
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 93.75%
#
#
# 33
# Epoch 6, Iteration 2
# Train Set Loss: 4.38
# Test Set Loss: 3.23
# Train set accuracy for a single minibatch: 84.38%
# Test set accuracy for a single minibatch: 93.75%
#
#
# 34
# Epoch 6, Iteration 3
# Train Set Loss: 3.47
# Test Set Loss: 3.19
# Train set accuracy for a single minibatch: 84.38%
# Test set accuracy for a single minibatch: 93.75%
#
#
# 35
# Epoch 6, Iteration 4
# Train Set Loss: 3.06
# Test Set Loss: 3.15
# Train set accuracy for a single minibatch: 87.50%
# Test set accuracy for a single minibatch: 93.75%
#
#
# 36
# Epoch 7, Iteration 0
# Train Set Loss: 3.74
# Test Set Loss: 3.12
# Train set accuracy for a single minibatch: 81.25%
# Test set accuracy for a single minibatch: 90.62%
#
#
# 37
# Epoch 7, Iteration 1
# Train Set Loss: 3.48
# Test Set Loss: 3.10
# Train set accuracy for a single minibatch: 87.50%
# Test set accuracy for a single minibatch: 90.62%
#
#
# 38
# Epoch 7, Iteration 2
# Train Set Loss: 3.25
# Test Set Loss: 3.08
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 90.62%
#
#
# 39
# Epoch 7, Iteration 3
# Train Set Loss: 3.42
# Test Set Loss: 3.06
# Train set accuracy for a single minibatch: 84.38%
# Test set accuracy for a single minibatch: 90.62%
#
#
# 40
# Epoch 7, Iteration 4
# Train Set Loss: 3.06
# Test Set Loss: 3.05
# Train set accuracy for a single minibatch: 78.12%
# Test set accuracy for a single minibatch: 90.62%
#
#
# 41
# Epoch 8, Iteration 0
# Train Set Loss: 3.06
# Test Set Loss: 3.04
# Train set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 90.62%
#
#
# 42
# Epoch 8, Iteration 1
# Train Set Loss: 3.34
# Test Set Loss: 3.03
# Train set accuracy for a single minibatch: 78.12%
# Test set accuracy for a single minibatch: 90.62%
#
#
# 43
# Epoch 8, Iteration 2
# Train Set Loss: 3.31
# Test Set Loss: 3.00
# Train set accuracy for a single minibatch: 78.12%
# Test set accuracy for a single minibatch: 90.62%
#
#
# 44
# Epoch 8, Iteration 3
# Train Set Loss: 3.29
# Test Set Loss: 2.98
# Train set accuracy for a single minibatch: 78.12%
# Test set accuracy for a single minibatch: 90.62%
#
#
# 45
# Epoch 8, Iteration 4
# Train Set Loss: 2.87
# Test Set Loss: 2.95
# Train set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 90.62%
#
#
# 46
# Epoch 9, Iteration 0
# Train Set Loss: 2.98
# Test Set Loss: 2.92
# Train set accuracy for a single minibatch: 87.50%
# Test set accuracy for a single minibatch: 90.62%
#
#
# 47
# Epoch 9, Iteration 1
# Train Set Loss: 2.85
# Test Set Loss: 2.90
# Train set accuracy for a single minibatch: 84.38%
# Test set accuracy for a single minibatch: 90.62%
#
#
# 48
# Epoch 9, Iteration 2
# Train Set Loss: 3.16
# Test Set Loss: 2.87
# Train set accuracy for a single minibatch: 87.50%
# Test set accuracy for a single minibatch: 90.62%
#
#
# 49
# Epoch 9, Iteration 3
# Train Set Loss: 3.00
# Test Set Loss: 2.82
# Train set accuracy for a single minibatch: 78.12%
# Test set accuracy for a single minibatch: 90.62%
#
#
# 50
# Epoch 9, Iteration 4
# Train Set Loss: 2.99
# Test Set Loss: 2.78
# Train set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 90.62%
#
#
# 51
# Epoch 10, Iteration 0
# Train Set Loss: 3.02
# Test Set Loss: 2.75
# Train set accuracy for a single minibatch: 84.38%
# Test set accuracy for a single minibatch: 90.62%
#
#
# 52
# Epoch 10, Iteration 1
# Train Set Loss: 2.70
# Test Set Loss: 2.72
# Train set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 93.75%
#
#
# 53
# Epoch 10, Iteration 2
# Train Set Loss: 3.08
# Test Set Loss: 2.68
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 93.75%
#
#
# 54
# Epoch 10, Iteration 3
# Train Set Loss: 2.54
# Test Set Loss: 2.66
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 93.75%
#
#
# 55
# Epoch 10, Iteration 4
# Train Set Loss: 2.80
# Test Set Loss: 2.64
# Train set accuracy for a single minibatch: 84.38%
# Test set accuracy for a single minibatch: 93.75%
#
#
# 56
# Epoch 11, Iteration 0
# Train Set Loss: 2.56
# Test Set Loss: 2.62
# Train set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 57
# Epoch 11, Iteration 1
# Train Set Loss: 2.41
# Test Set Loss: 2.60
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 58
# Epoch 11, Iteration 2
# Train Set Loss: 2.91
# Test Set Loss: 2.57
# Train set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 59
# Epoch 11, Iteration 3
# Train Set Loss: 2.68
# Test Set Loss: 2.54
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 60
# Epoch 11, Iteration 4
# Train Set Loss: 2.96
# Test Set Loss: 2.52
# Train set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 61
# Epoch 12, Iteration 0
# Train Set Loss: 2.62
# Test Set Loss: 2.50
# Train set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 62
# Epoch 12, Iteration 1
# Train Set Loss: 2.29
# Test Set Loss: 2.48
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 63
# Epoch 12, Iteration 2
# Train Set Loss: 2.56
# Test Set Loss: 2.46
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 64
# Epoch 12, Iteration 3
# Train Set Loss: 2.78
# Test Set Loss: 2.44
# Train set accuracy for a single minibatch: 87.50%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 65
# Epoch 12, Iteration 4
# Train Set Loss: 2.62
# Test Set Loss: 2.42
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 66
# Epoch 13, Iteration 0
# Train Set Loss: 2.46
# Test Set Loss: 2.41
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 67
# Epoch 13, Iteration 1
# Train Set Loss: 2.43
# Test Set Loss: 2.39
# Train set accuracy for a single minibatch: 87.50%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 68
# Epoch 13, Iteration 2
# Train Set Loss: 2.50
# Test Set Loss: 2.38
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 69
# Epoch 13, Iteration 3
# Train Set Loss: 2.57
# Test Set Loss: 2.36
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 70
# Epoch 13, Iteration 4
# Train Set Loss: 2.34
# Test Set Loss: 2.33
# Train set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 71
# Epoch 14, Iteration 0
# Train Set Loss: 2.38
# Test Set Loss: 2.31
# Train set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 72
# Epoch 14, Iteration 1
# Train Set Loss: 2.53
# Test Set Loss: 2.29
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 73
# Epoch 14, Iteration 2
# Train Set Loss: 2.28
# Test Set Loss: 2.26
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 74
# Epoch 14, Iteration 3
# Train Set Loss: 2.27
# Test Set Loss: 2.23
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 75
# Epoch 14, Iteration 4
# Train Set Loss: 2.27
# Test Set Loss: 2.21
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 76
# Epoch 15, Iteration 0
# Train Set Loss: 2.24
# Test Set Loss: 2.21
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 77
# Epoch 15, Iteration 1
# Train Set Loss: 2.24
# Test Set Loss: 2.18
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 78
# Epoch 15, Iteration 2
# Train Set Loss: 2.24
# Test Set Loss: 2.16
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 79
# Epoch 15, Iteration 3
# Train Set Loss: 2.38
# Test Set Loss: 2.13
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 80
# Epoch 15, Iteration 4
# Train Set Loss: 2.08
# Test Set Loss: 2.10
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 81
# Epoch 16, Iteration 0
# Train Set Loss: 1.94
# Test Set Loss: 2.08
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 82
# Epoch 16, Iteration 1
# Train Set Loss: 2.31
# Test Set Loss: 2.05
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 83
# Epoch 16, Iteration 2
# Train Set Loss: 2.22
# Test Set Loss: 2.03
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 100.00%
#
#
# 84
# Epoch 16, Iteration 3
# Train Set Loss: 1.98
# Test Set Loss: 2.01
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 100.00%
#
#
# 85
# Epoch 16, Iteration 4
# Train Set Loss: 2.20
# Test Set Loss: 1.99
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 86
# Epoch 17, Iteration 0
# Train Set Loss: 2.11
# Test Set Loss: 1.97
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 96.88%
#
#
# 87
# Epoch 17, Iteration 1
# Train Set Loss: 2.05
# Test Set Loss: 1.95
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 100.00%
#
#
# 88
# Epoch 17, Iteration 2
# Train Set Loss: 2.12
# Test Set Loss: 1.93
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 100.00%
#
#
# 89
# Epoch 17, Iteration 3
# Train Set Loss: 1.84
# Test Set Loss: 1.92
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 100.00%
#
#
# 90
# Epoch 17, Iteration 4
# Train Set Loss: 1.99
# Test Set Loss: 1.91
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 100.00%
#
#
# 91
# Epoch 18, Iteration 0
# Train Set Loss: 1.98
# Test Set Loss: 1.89
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 100.00%
#
#
# 92
# Epoch 18, Iteration 1
# Train Set Loss: 1.97
# Test Set Loss: 1.87
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 100.00%
#
#
# 93
# Epoch 18, Iteration 2
# Train Set Loss: 1.91
# Test Set Loss: 1.85
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 100.00%
#
#
# 94
# Epoch 18, Iteration 3
# Train Set Loss: 1.91
# Test Set Loss: 1.84
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 100.00%
#
#
# 95
# Epoch 18, Iteration 4
# Train Set Loss: 1.85
# Test Set Loss: 1.82
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 100.00%
#
#
# 96
# Epoch 19, Iteration 0
# Train Set Loss: 1.99
# Test Set Loss: 1.80
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 100.00%
#
#
# 97
# Epoch 19, Iteration 1
# Train Set Loss: 1.80
# Test Set Loss: 1.78
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 100.00%
#
#
# 98
# Epoch 19, Iteration 2
# Train Set Loss: 1.71
# Test Set Loss: 1.77
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 100.00%
#
#
# 99
# Epoch 19, Iteration 3
# Train Set Loss: 1.88
# Test Set Loss: 1.75
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 100.00%
#
#
# 100
# Epoch 19, Iteration 4
# Train Set Loss: 1.77
# Test Set Loss: 1.73
# Train set accuracy for a single minibatch: 100.00%
# Test set accuracy for a single minibatch: 100.00%

# %%
# Plot Loss
fig = plt.figure(facecolor="w", figsize=(10, 5))
plt.plot(loss_hist)
plt.plot(test_loss_hist)
plt.title("Loss Curves")
plt.legend(["Train Loss", "Test Loss"])
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

# %%
for samples, labels in test_loader:
    

    output = net(samples[3])
    print()
    print(labels[3])

    tensor_output = output[0]  # Extract the tensor from the tuple
    numpy_array = tensor_output.detach().numpy()  # Convert tensor to numpy array
    plt.plot(numpy_array)
    # Plot the numpy array
    plt.plot(numpy_array)
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.title('Plot of Tensor')
    plt.show()
# Out:
# tensor(0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7188\1880285545.py:18: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   return torch.tensor(sample, dtype=torch.float32), torch.tensor(label, dtype=torch.long)
# tensor(1)

# %%
print(len(numpy_array))
# Out:
# 25

# %%
params = list(net.parameters())

# Print the parameters
for param in params:
    print(param)
# Out:
# Parameter containing:
# tensor([[ 0.0815, -0.1125, -0.1012,  ..., -0.0377, -0.0446,  0.0041],
#         [ 0.0168, -0.0652,  0.0332,  ..., -0.1229,  0.0718, -0.0938],
#         [-0.1133,  0.0806, -0.0684,  ...,  0.1042, -0.0887,  0.0267],
#         ...,
#         [-0.1007, -0.0272,  0.0632,  ..., -0.0552, -0.0244, -0.0043],
#         [ 0.0943,  0.1028,  0.0033,  ..., -0.0104,  0.0594, -0.1128],
#         [ 0.0421, -0.0119, -0.0056,  ...,  0.0980,  0.0383, -0.0098]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 3.0717e-02,  2.7248e-02,  9.9089e-02, -7.7826e-02,  4.9177e-02,
#         -6.0562e-02, -9.0090e-02, -6.5847e-02, -5.7834e-02, -7.5927e-02,
#          5.0247e-02,  6.9204e-02, -1.2005e-01,  1.2264e-01, -4.6459e-02,
#          1.1577e-01,  1.1139e-01, -4.7919e-02,  1.0890e-01, -9.4224e-02,
#         -1.3633e-02, -3.5736e-02, -1.1271e-01,  1.0222e-01,  1.0971e-01,
#         -2.1832e-02, -7.9587e-02, -7.0239e-02, -8.0314e-02, -1.2413e-01,
#          3.5936e-02,  8.1563e-02, -9.5608e-02,  1.1725e-01,  2.3563e-02,
#         -9.4563e-02, -8.1076e-02,  1.1440e-03,  1.6721e-02, -4.6253e-03,
#          8.8181e-02,  3.7983e-02,  7.8520e-03,  1.0728e-01, -8.2721e-02,
#         -1.0041e-01,  2.1404e-02, -7.2291e-03,  1.1627e-02, -1.5955e-03,
#         -9.7850e-02, -1.2964e-02,  9.9665e-03,  8.4652e-02,  3.3359e-02,
#          1.1757e-01,  1.1610e-03,  8.4351e-02, -1.9806e-02, -3.7572e-02,
#         -1.0576e-01,  7.9050e-02, -1.1913e-01,  9.3464e-02,  5.6416e-02,
#          4.1293e-02,  6.6243e-02,  5.3933e-03,  4.7078e-02, -6.5232e-02,
#         -1.2089e-01, -1.2282e-01, -9.3834e-02,  1.1614e-01, -6.7155e-02,
#         -9.6767e-02, -1.0013e-02, -8.2620e-02,  5.3420e-02,  1.2616e-01,
#         -8.5550e-02,  1.5519e-02,  1.2742e-01, -8.2075e-02,  1.1613e-01,
#         -5.8561e-02,  6.0285e-02,  9.0482e-02,  1.0532e-01,  4.2636e-02,
#         -1.1133e-01,  8.0786e-02,  4.9350e-02,  1.3088e-01, -2.6062e-03,
#         -5.5436e-02,  5.5664e-02, -2.4640e-02,  4.7665e-02, -7.2981e-02,
#         -5.1669e-02, -5.9024e-02, -2.8695e-03,  1.0045e-01,  1.0065e-01,
#         -8.4333e-03,  1.1345e-01,  8.2653e-02, -7.8085e-02,  9.3208e-03,
#         -8.0412e-02, -6.1268e-02, -4.8722e-02,  7.4674e-02, -9.2954e-02,
#         -9.8274e-02,  3.9211e-02, -3.3615e-02, -8.2771e-03, -4.0216e-02,
#         -3.2680e-02,  7.0086e-03,  1.1075e-01,  8.6833e-02,  7.4690e-02,
#          1.3568e-01, -1.2344e-01,  1.5095e-02,  6.0074e-02, -2.8583e-02,
#         -6.0574e-02,  5.9290e-02,  5.9193e-02,  9.2133e-02, -5.4396e-02,
#          1.1461e-01,  1.3214e-01, -6.9154e-02, -6.6510e-02,  1.1963e-01,
#         -5.7177e-02, -5.1078e-02,  5.8227e-03,  1.4831e-02, -2.4274e-02,
#         -9.3621e-02,  4.5809e-02,  8.9077e-02,  9.3207e-02,  2.2797e-02,
#          3.5842e-02, -1.0741e-01, -2.8267e-02,  4.2067e-03, -3.5008e-02,
#         -1.1539e-01,  1.2655e-01, -4.8294e-02,  7.4682e-02, -9.3731e-02,
#         -8.5854e-04, -7.6065e-02,  6.7380e-02, -2.9779e-02,  8.5907e-02,
#         -1.2402e-02, -2.4727e-02, -4.4411e-02,  2.9917e-02,  7.5692e-02,
#          7.5375e-02, -1.1116e-01,  5.2652e-02, -2.1515e-02, -1.2549e-01,
#          9.6741e-02,  8.5975e-02, -7.8359e-02,  2.5329e-02, -1.1768e-01,
#         -4.7415e-02,  3.7173e-02,  1.0594e-02, -1.0859e-01,  3.0390e-02,
#         -6.6560e-02, -2.9066e-02,  1.1703e-01,  5.9719e-03,  8.0100e-04,
#          1.1665e-02, -2.4003e-02, -1.0413e-01,  1.1672e-01, -1.0986e-01,
#         -1.0855e-01,  1.1891e-01, -9.9492e-02,  7.5094e-02, -1.1061e-01,
#         -2.4443e-03, -2.2453e-02, -1.1498e-01,  7.7126e-02,  8.3887e-02,
#         -5.3389e-02,  3.5080e-02,  4.2405e-02,  9.5070e-02,  9.4306e-02,
#          2.2662e-02, -5.5896e-02,  5.9539e-02, -3.5467e-02, -1.0134e-01,
#          1.2337e-01, -1.2572e-01,  1.0060e-01,  5.7781e-02,  1.0044e-01,
#         -6.5406e-03,  4.8671e-02,  1.1714e-01,  7.3316e-02, -1.0999e-01,
#         -7.9556e-02, -3.0643e-02, -7.3749e-02, -5.5196e-02,  1.2920e-01,
#          9.4447e-02, -7.3451e-02,  1.5268e-02,  4.1536e-02,  7.5930e-02,
#          7.9658e-02,  2.9180e-02, -7.3139e-02,  5.3315e-02, -4.2503e-03,
#          7.1002e-02, -5.3469e-02,  7.7537e-02,  5.1696e-02, -5.8160e-02,
#         -3.7056e-02, -4.3444e-03, -6.8371e-02, -4.5978e-02, -2.5670e-02,
#         -5.2534e-04, -8.0587e-02,  3.3165e-02,  9.1893e-02,  1.0549e-01,
#          5.9132e-02,  5.2995e-02, -1.3003e-01, -1.2405e-01, -1.1494e-01,
#         -1.1888e-01,  1.3016e-01, -5.0784e-02, -9.2847e-02, -5.7720e-02,
#         -2.2072e-02,  1.0045e-01,  3.4806e-02, -8.8477e-02, -6.0038e-02,
#          4.3414e-02, -1.0236e-01,  5.8343e-02, -1.8449e-03,  7.3837e-02,
#         -3.7714e-02,  9.2931e-02,  7.6038e-02,  1.1748e-01,  1.5439e-02,
#         -1.0815e-01,  1.2343e-01, -4.0671e-02, -3.3225e-02, -1.8290e-02,
#          8.5165e-02, -2.6328e-02,  6.1155e-02,  1.2369e-01,  4.4344e-02,
#          1.1502e-01,  8.0577e-02,  1.0058e-01, -8.4808e-03,  8.1545e-02,
#          9.0061e-02,  3.1482e-02, -9.9954e-02, -4.9185e-02, -7.8038e-04,
#         -5.5483e-02, -6.6407e-02,  1.3085e-02, -4.1412e-02, -2.4917e-02,
#         -4.5995e-02, -5.8994e-02,  1.2343e-01, -4.3884e-02, -8.0653e-02,
#          9.2067e-02,  4.1395e-02,  2.8549e-02, -1.1838e-01, -3.3409e-02,
#         -4.1971e-02, -8.7537e-02, -4.2053e-02, -4.7444e-02, -2.0409e-02,
#         -8.1015e-02, -7.2840e-02, -6.2135e-02,  1.2045e-01,  3.6424e-02,
#         -7.7759e-02, -2.0976e-02,  8.3597e-02,  2.2431e-02,  1.2649e-01,
#          1.1013e-01, -6.9161e-03, -2.9603e-02, -8.4574e-02,  2.0813e-02,
#          1.9701e-02,  1.1550e-01,  5.1726e-02, -3.0739e-02, -4.7728e-02,
#         -1.2561e-01, -5.4429e-02, -5.0621e-02,  1.7732e-02,  1.0728e-01,
#         -6.4136e-02,  3.8696e-02,  1.1898e-01, -3.4784e-02,  1.3117e-02,
#         -7.3884e-02,  2.7129e-02, -6.7601e-03, -1.2660e-01, -8.8460e-02,
#          1.5419e-01, -1.1534e-01, -7.7340e-02, -5.3324e-02,  5.9421e-02,
#          1.1816e-01,  3.3143e-02,  8.9267e-02, -6.6688e-03,  7.4984e-02,
#          4.0504e-02,  1.0169e-01,  5.9875e-02, -1.0914e-04,  3.5311e-02,
#         -1.9395e-02,  3.9002e-02,  8.9807e-02,  7.0862e-02,  1.1901e-01,
#          4.3194e-02, -5.7294e-02,  4.9923e-02,  7.1627e-02,  6.5409e-02,
#          1.2130e-01,  9.1666e-05, -1.0841e-01, -7.3152e-02, -1.4199e-02,
#          1.2038e-01,  9.1940e-02, -9.0730e-02, -3.5397e-02,  5.8255e-02,
#          9.8832e-02, -5.9425e-02, -8.5821e-02, -1.1148e-01,  4.3971e-02,
#          6.4246e-02,  8.5364e-02,  8.4969e-02,  7.6072e-02, -4.8499e-04,
#          1.0647e-01,  1.9761e-02,  1.0594e-01,  9.8079e-02, -7.0025e-02,
#          2.2674e-02,  7.7692e-02, -6.8799e-02,  9.7551e-02,  1.0311e-01,
#          1.1488e-01,  1.2032e-01,  9.3059e-02, -9.5760e-02, -5.4558e-02,
#         -1.2185e-01, -1.0186e-01, -3.2737e-02, -6.8212e-02,  5.2958e-02,
#         -7.5594e-02,  9.0828e-02,  2.1452e-02, -7.4665e-02,  4.6006e-02,
#         -1.1096e-01,  7.7092e-02, -1.1741e-01, -1.2049e-01, -9.1397e-02,
#          5.2482e-02, -1.1140e-01, -1.2694e-02, -7.2475e-03, -3.5425e-02,
#          6.1523e-02,  9.8472e-02, -2.4259e-02,  1.1869e-01,  3.0908e-03,
#          4.7725e-02,  1.1210e-01,  7.8026e-02,  2.8138e-02,  1.2735e-01,
#         -6.2859e-02, -3.3687e-02,  1.1507e-01,  5.4822e-02,  9.2313e-02,
#         -1.3290e-03,  8.9683e-03,  8.0973e-02, -1.0741e-02,  3.3958e-02,
#         -2.6028e-02,  2.7303e-02,  2.5784e-02,  1.0978e-01,  3.6113e-02,
#          1.1249e-01, -1.2208e-01,  2.6080e-02, -1.0566e-01,  1.6113e-02,
#          1.1104e-02,  7.9273e-03,  8.7620e-02,  1.2501e-01, -6.0968e-02,
#          1.1754e-01,  1.2085e-01,  1.0156e-01,  6.2507e-02,  4.0887e-02,
#         -8.3181e-02, -1.2301e-01, -6.3410e-02,  2.4766e-02,  3.1532e-02,
#         -2.4747e-02, -6.5728e-02, -6.3302e-02, -1.1480e-01, -1.2018e-01,
#          5.7143e-02, -8.2475e-02,  8.1474e-02,  1.2146e-01, -6.4071e-02,
#         -3.7824e-03, -1.2207e-01,  3.7266e-02, -7.5584e-02,  2.3922e-02,
#          5.5332e-02, -6.9891e-02,  8.2947e-02,  6.3829e-02, -1.1485e-01,
#          1.1728e-01, -7.9218e-02, -4.0128e-02,  7.2158e-02, -5.4422e-02,
#          1.2527e-01, -5.8897e-02,  8.2770e-02, -1.0748e-01, -1.1565e-01,
#         -1.3004e-01, -3.4713e-02,  8.0287e-02, -9.1956e-02, -8.5052e-02,
#          1.1163e-01,  8.5213e-02, -1.1656e-01,  2.9792e-02,  1.1496e-01,
#          3.5719e-02,  6.5784e-02, -1.9684e-02,  4.0980e-02, -2.1873e-02,
#          4.2281e-02, -1.3576e-02, -9.2970e-02, -7.5227e-02,  5.4442e-02,
#         -6.9583e-02, -8.3761e-02,  1.2858e-03,  1.2738e-01, -6.2999e-02,
#          2.0446e-02, -1.2416e-01,  7.4824e-02, -1.2877e-01,  3.9875e-03,
#         -6.0324e-02, -6.0704e-02, -7.0643e-02,  6.0122e-02, -4.2582e-02,
#          8.9327e-02, -2.8586e-02,  8.5621e-02, -1.2760e-01,  9.2113e-02,
#         -1.2301e-01,  8.7926e-02, -1.1482e-01,  5.7048e-02, -6.7583e-02,
#         -3.9863e-02,  9.8083e-02,  6.2774e-03,  2.1593e-02,  1.0707e-01,
#          5.2780e-02,  1.0968e-03,  5.8307e-02, -7.5611e-02,  3.4201e-03,
#         -4.7858e-02,  9.6587e-02,  4.4534e-02, -8.1936e-02, -1.8668e-02,
#         -7.5325e-02, -1.1107e-01,  4.9005e-03,  1.2468e-01,  3.7615e-02,
#         -5.6660e-03,  6.5756e-02,  4.7461e-02, -5.7219e-02,  1.0755e-01,
#         -1.5289e-02,  1.7399e-02, -1.1747e-01,  3.1892e-05, -9.7564e-02,
#          1.3799e-02, -1.1550e-01,  3.5174e-02, -1.1145e-02, -5.1316e-02,
#          4.7474e-02, -9.7892e-02, -9.4536e-02, -8.4916e-02, -2.3963e-02,
#         -6.3044e-02, -7.9476e-02, -1.7122e-02, -3.2010e-02,  6.5584e-02,
#         -2.2473e-02,  8.6269e-02, -3.8542e-02,  1.1856e-01, -1.1277e-01,
#         -8.3582e-02,  9.2120e-02, -1.2287e-01, -9.1743e-02, -3.3121e-02,
#         -7.7136e-02, -6.0939e-02,  7.6642e-02,  1.4093e-02, -3.8212e-02,
#         -5.9418e-02, -4.2587e-03, -6.8358e-02, -1.1443e-02,  9.5304e-02,
#         -4.5923e-02,  5.4628e-02,  6.5314e-03,  8.3986e-02,  7.8448e-02,
#          3.9968e-02,  3.1570e-03,  9.9098e-02, -8.6115e-02, -7.9237e-02,
#          5.5666e-02,  1.0948e-02, -7.8155e-02, -1.2388e-01, -9.4729e-02,
#         -4.6853e-02,  3.8262e-02,  3.7636e-02, -8.8219e-02, -4.4202e-02,
#          2.7102e-02, -9.9000e-02,  3.6561e-02,  4.0768e-02,  1.2760e-01,
#         -1.0156e-01,  8.6924e-02,  1.0456e-01, -6.6434e-02, -1.1626e-01,
#         -1.0026e-01, -6.5922e-02,  9.3264e-02, -9.4562e-02,  9.7987e-02,
#         -1.7391e-02,  3.2623e-02,  1.1786e-01,  1.7102e-02, -1.4488e-03,
#          5.7188e-02, -4.1620e-02, -8.2451e-03, -7.4099e-02,  1.2198e-01,
#         -7.1155e-02, -8.6522e-02,  1.2826e-01,  9.6560e-02,  1.1422e-01,
#          2.6627e-02,  2.3298e-02,  1.1697e-01,  7.2140e-02,  4.6375e-02,
#          6.8809e-03,  7.8457e-02, -3.8207e-02, -1.0578e-01,  1.0394e-01,
#          4.3653e-02,  3.1658e-02,  8.8488e-03,  1.1731e-01, -6.2877e-02,
#          8.4412e-02,  7.8767e-02, -3.9774e-02, -1.1881e-01,  9.9341e-02,
#          1.1056e-01, -4.1791e-02,  9.4295e-02,  8.3897e-02,  1.1247e-01,
#         -1.3264e-01,  3.7934e-02, -7.0375e-02, -9.5135e-02, -1.0839e-01,
#         -7.2302e-02, -6.8243e-02,  7.5041e-02,  5.5233e-02,  1.1288e-01,
#          1.2052e-01,  4.6938e-02,  9.2884e-02,  7.8893e-02, -9.0558e-02,
#          4.3440e-02, -5.5864e-02, -2.9213e-02, -1.1696e-01, -6.2420e-02,
#          6.5889e-02, -5.2147e-02, -7.0334e-02,  8.5864e-02,  7.5118e-02,
#          7.0713e-02, -1.1391e-01, -8.9366e-02,  1.0975e-01, -1.2485e-02,
#          4.8611e-02,  5.2474e-02,  6.9850e-02,  1.1843e-01, -3.1216e-02,
#         -8.9252e-02, -4.6612e-03,  5.1496e-02,  3.0116e-03,  1.0167e-01,
#          4.6965e-02,  5.1772e-02, -1.0271e-01, -3.9243e-02,  2.5495e-02,
#         -1.0392e-01,  5.1393e-02, -1.1726e-01,  9.7536e-02,  1.3482e-02,
#          6.8595e-03, -8.4161e-02,  8.8274e-02,  4.4523e-02, -5.1345e-02,
#         -7.6790e-02, -8.2898e-02,  1.1221e-01, -4.6410e-02, -2.9279e-02,
#         -6.9014e-02,  1.0478e-01, -7.1370e-02,  2.6545e-03, -1.0738e-01,
#         -1.1452e-01, -8.4837e-02, -1.1115e-01, -1.6045e-02, -2.4048e-02,
#         -1.2547e-03,  8.9438e-02, -6.8607e-02, -8.9578e-02, -4.5814e-02,
#         -1.2505e-01, -5.0504e-02, -6.4317e-02, -1.1985e-01,  9.3588e-04,
#         -5.3453e-03,  6.1776e-02,  4.8470e-02, -4.8140e-02,  3.2102e-02,
#         -1.0117e-01,  1.0782e-02,  4.0788e-02,  1.0698e-01,  6.6526e-02,
#          6.6677e-03, -3.0494e-02, -4.9243e-03,  5.8131e-02,  6.6559e-03,
#         -9.3179e-02, -5.9182e-02,  6.8033e-02,  1.0351e-01,  9.5689e-02,
#         -1.5341e-02,  6.1027e-03,  1.0940e-01,  1.2392e-01,  1.1776e-02,
#          2.5435e-02, -6.5124e-02, -1.2638e-01,  8.4000e-02,  3.9014e-02,
#         -1.4401e-02,  2.2220e-02,  1.3576e-01, -1.2951e-01,  1.9803e-02,
#          1.2311e-01,  6.6865e-02, -1.7126e-02,  7.7113e-02, -1.8618e-02,
#          5.2856e-03,  4.0629e-02, -1.0152e-01, -4.0547e-02,  9.1144e-02,
#          6.3989e-02,  7.4863e-02,  1.0502e-01, -6.7855e-02, -1.0703e-01,
#         -1.1980e-01,  6.0374e-02,  7.2516e-02, -2.7649e-02, -1.2204e-02,
#          2.9515e-02, -5.6635e-03, -8.9683e-02, -1.1496e-01,  4.0068e-02,
#         -1.2847e-02,  1.1043e-01, -5.2407e-02,  1.3014e-01, -3.4596e-02,
#          2.1445e-03, -4.2805e-02,  1.1627e-01, -6.3902e-02, -6.3094e-04,
#         -2.8428e-02,  1.0793e-01,  1.1834e-01, -9.3783e-02, -1.0882e-01,
#          7.8820e-02, -3.4161e-02,  6.5173e-02,  6.1031e-02,  2.3860e-02,
#          9.5900e-02,  1.2957e-01,  9.2120e-02,  3.5272e-02, -3.2521e-02,
#         -9.3229e-02,  4.7559e-02, -7.1807e-02, -1.2411e-01,  5.3001e-02,
#         -5.4527e-02,  2.5040e-02, -2.6748e-02, -3.8139e-03,  1.1270e-01,
#          1.1439e-01,  1.1074e-01,  8.5329e-03,  4.2246e-02, -1.1775e-01,
#         -6.0226e-02,  9.8618e-02,  3.5620e-02, -3.4358e-02,  3.5395e-02,
#         -4.5202e-02,  5.7020e-02,  9.4782e-02, -6.2030e-02, -4.8148e-02,
#          3.0970e-02, -8.2403e-02,  1.0492e-01,  1.1016e-02,  1.2348e-01,
#         -8.2691e-02, -1.1442e-01,  8.4116e-04,  9.2327e-02,  8.7619e-02,
#         -3.0195e-02,  1.1090e-01, -8.9104e-02,  1.0915e-01, -1.1978e-01,
#          5.9030e-02, -1.0126e-01, -7.4515e-03,  8.2193e-02,  2.6566e-02,
#         -1.0122e-01, -7.8375e-02, -8.5436e-02, -1.2022e-02,  1.4690e-01,
#          4.1746e-02,  1.0993e-01, -8.4778e-02,  1.2294e-01, -6.6099e-02,
#          7.1741e-02, -7.7493e-02, -6.5170e-03,  7.2055e-02,  4.7613e-02,
#          4.2060e-03,  8.0986e-02, -1.0040e-01, -1.1292e-01, -8.1626e-02,
#          1.1426e-01, -5.6098e-02,  3.3439e-02,  9.2115e-03,  1.1514e-01,
#         -2.1038e-02, -6.5103e-02,  1.2360e-01,  1.0601e-01,  7.2274e-02,
#         -3.4438e-02,  5.7718e-02,  1.0531e-02, -5.4674e-02,  8.0640e-02,
#          1.2188e-01,  9.9219e-02, -2.0482e-02,  1.1924e-01,  9.1684e-02,
#         -9.1331e-02,  2.4422e-02,  1.3261e-02,  8.7030e-02, -1.0963e-01,
#          2.5055e-02, -3.2802e-03, -1.1860e-01,  1.1492e-02, -1.4879e-02,
#          1.1471e-01, -1.1926e-01, -3.2071e-02, -9.0669e-02,  2.0875e-02,
#          3.1848e-02,  6.7419e-02, -6.9086e-02, -2.5123e-02,  8.7877e-02,
#          2.1305e-02,  1.2628e-02, -3.4059e-02,  1.2169e-01,  4.6704e-02,
#         -1.0711e-01, -5.1975e-02, -7.2492e-02, -4.1240e-02, -1.1083e-01,
#          3.0940e-02, -1.2560e-01,  3.8658e-02,  3.3482e-02,  6.0904e-02,
#          5.6935e-02,  3.8785e-02, -2.6468e-02,  8.8940e-02, -5.6024e-02,
#         -3.1832e-02, -3.0306e-02,  1.1314e-02,  8.2186e-02, -1.1818e-01,
#         -1.2040e-01, -2.9840e-02, -2.4065e-02,  3.8371e-02,  7.3164e-02,
#          1.2166e-01, -3.2153e-02,  3.3430e-02,  8.6215e-02, -8.9522e-02],
#        requires_grad=True)
# Parameter containing:
# tensor([[ 0.0110,  0.0122,  0.0023,  ..., -0.0314,  0.0168,  0.0127],
#         [ 0.0046,  0.0196,  0.0156,  ...,  0.0199,  0.0181, -0.0125]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.0270, -0.0083], requires_grad=True)

# %%
for samples, labels in test_loader:
    print(samples.size)
    output = net(samples[3])
    print(labels[3])
# Out:
# <built-in method size of Tensor object at 0x00000206C78E5B30>
# tensor(0)
# <built-in method size of Tensor object at 0x00000206C78D15E0>
# tensor(1)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7188\1880285545.py:18: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   return torch.tensor(sample, dtype=torch.float32), torch.tensor(label, dtype=torch.long)

# %%
spk_In = torch.stack(net.spkIn)
spk_rec1 = torch.stack(net.spk1)
spk_rec2 = torch.stack(net.spk2)

# %%
len(net.spkIn[0])
# Out:
# 59

# %%
for samples, labels in test_loader:
    print(len(samples[2]))
    output = net(samples[2])
    print(len(net.spkIn))
    print(len(output))
    print(labels[2])
    #spk_In = torch.stack(net.spkIn)
    spk_rec1 = torch.stack(net.spk1)
    spk_rec2 = torch.stack(net.spk2)
    plot_snn_spikes_modified(net.spkIn[0], spk_rec1, spk_rec2, num_steps, "Fully Connected Spiking Neural Network")
# Out:
# 59
# 25
# 2
# tensor(0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7188\1880285545.py:18: DeprecationWarning: an integer is required (got type numpy.float64).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   return torch.tensor(sample, dtype=torch.float32), torch.tensor(label, dtype=torch.long)
# 59
# 25
# 2
# tensor(1)

# %%
spk_In = torch.stack(net.spkIn[])
spk_rec1 = torch.stack(net.spk1)
spk_rec2 = torch.stack(net.spk2)
# Out:
#   Cell In[233], line 1
#     spk_In = torch.stack(net.spkIn[])
#                                    ^
# SyntaxError: invalid syntax

# %%
plot_snn_spikes(spk_In, spk_rec1, spk_rec2, num_steps, "Fully Connected Spiking Neural Network")

# %%
import matplotlib.pyplot as plt

# Sample data
neuron_numbers = list(range(59))
currents = net.spkIn[0].tolist()  # Currents fed to each neuron

# Create bar chart
plt.bar(neuron_numbers, currents, color='skyblue')

# Add labels and title
plt.xlabel('Neuron Numbers')
plt.ylabel('Currents')
plt.title('Currents Fed to Neurons')

# Show plot
plt.show()

# %%
len(neuron_numbers)
